# %%
import pandas as pd
import numpy as np 
import random
from collections import Counter
from sklearn.model_selection import train_test_split
from imblearn.under_sampling import RandomUnderSampler
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from category_encoders.woe import WOEEncoder
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score, roc_auc_score
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA
from xgboost import XGBClassifier

np.random.seed(42)
random.seed(42)

# %%
df_identity = pd.read_csv("identity.csv")
df_identity
# Out:
#         TransactionID  id_01     id_02  id_03  id_04  id_05  id_06  id_07  \
# 0             2987004    0.0   70787.0    NaN    NaN    NaN    NaN    NaN
# 1             2987008   -5.0   98945.0    NaN    NaN    0.0   -5.0    NaN
# 2             2987010   -5.0  191631.0    0.0    0.0    0.0    0.0    NaN
# 3             2987011   -5.0  221832.0    NaN    NaN    0.0   -6.0    NaN
# 4             2987016    0.0    7460.0    0.0    0.0    1.0    0.0    NaN
# ...               ...    ...       ...    ...    ...    ...    ...    ...
# 144228        3577521  -15.0  145955.0    0.0    0.0    0.0    0.0    NaN
# 144229        3577526   -5.0  172059.0    NaN    NaN    1.0   -5.0    NaN
# 144230        3577529  -20.0  632381.0    NaN    NaN   -1.0  -36.0    NaN
# 144231        3577531   -5.0   55528.0    0.0    0.0    0.0   -7.0    NaN
# 144232        3577534  -45.0  339406.0    NaN    NaN  -10.0 -100.0    NaN
#
#         id_08  id_09  ...                    id_31  id_32      id_33  \
# 0         NaN    NaN  ...      samsung browser 6.2   32.0  2220x1080
# 1         NaN    NaN  ...       mobile safari 11.0   32.0   1334x750
# 2         NaN    0.0  ...              chrome 62.0    NaN        NaN
# 3         NaN    NaN  ...              chrome 62.0    NaN        NaN
# 4         NaN    0.0  ...              chrome 62.0   24.0   1280x800
# ...       ...    ...  ...                      ...    ...        ...
# 144228    NaN    0.0  ...  chrome 66.0 for android    NaN        NaN
# 144229    NaN    NaN  ...  chrome 55.0 for android   32.0    855x480
# 144230    NaN    NaN  ...  chrome 65.0 for android    NaN        NaN
# 144231    NaN    0.0  ...              chrome 66.0   24.0  2560x1600
# 144232    NaN    NaN  ...  chrome 66.0 for android    NaN        NaN
#
#                  id_34  id_35 id_36 id_37  id_38  DeviceType  \
# 0       match_status:2      T     F     T      T      mobile
# 1       match_status:1      T     F     F      T      mobile
# 2                  NaN      F     F     T      T     desktop
# 3                  NaN      F     F     T      T     desktop
# 4       match_status:2      T     F     T      T     desktop
# ...                ...    ...   ...   ...    ...         ...
# 144228             NaN      F     F     T      F      mobile
# 144229  match_status:2      T     F     T      F      mobile
# 144230             NaN      F     F     T      F      mobile
# 144231  match_status:2      T     F     T      F     desktop
# 144232             NaN      F     F     T      F      mobile
#
#                                 DeviceInfo
# 0            SAMSUNG SM-G892A Build/NRD90M
# 1                               iOS Device
# 2                                  Windows
# 3                                      NaN
# 4                                    MacOS
# ...                                    ...
# 144228             F3111 Build/33.3.A.1.97
# 144229                 A574BL Build/NMF26F
# 144230  Moto E (4) Plus Build/NMA26.42-152
# 144231                               MacOS
# 144232         RNE-L03 Build/HUAWEIRNE-L03
#
# [144233 rows x 41 columns]

# %%
df_transaction = pd.read_csv("transaction.csv")

# %%
merge_df = pd.merge(df_transaction, df_identity, on= 'TransactionID', how = 'left')

# %%
# Наш файл очень много весит, попробуем уменьшить его

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %%
main_df = reduce_mem_usage(merge_df)
# Out:
# Mem. usage decreased to 650.48 Mb (66.8% reduction)

# %% [markdown]
# # Preprocess

# %%
# Добавим новый признак, а именно переведем секунды в часы

def make_hour_feature(f):
    #Creates an hour of the day feature, encoded as 0-23.  
    hours = f / (3600)        
    encoded_hours = np.floor(hours) % 24
    return encoded_hours

main_df['hour'] = make_hour_feature(main_df['TransactionDT'])
# Out:
# C:\Users\Никита\AppData\Local\Temp\ipykernel_2072\1074908976.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   main_df['hour'] = make_hour_feature(main_df['TransactionDT'])

# %%
# Создаим списики с категориальными и числовыми признаками

list_cat_col = main_df.select_dtypes(include=["object"]).columns.to_list()

exclude = ['TransactionID', 'TransactionDT', 'isFraud']

num_features = [f for f in main_df.columns if (f not in list_cat_col) & (f not in exclude)]

# %%
# Уберем признаки с 90% пропусками
col_na = main_df.isna().sum()
to_drop = col_na[(col_na / main_df.shape[0]) > 0.9].index

use_cols = [f for f in main_df.columns if f not in to_drop]
list_cat_col = [f for f in list_cat_col if f not in to_drop]
num_features = [f for f in num_features if f not in to_drop]

main_df[list_cat_col] = main_df[list_cat_col].astype(str)
main_df[num_features] = main_df[num_features].astype(np.float64)
main_df = main_df[use_cols]

# %%
# Заполним средним числом числовые признаки, а категориальные 'missing'
median_values = main_df[num_features].median() 

main_df[num_features] = main_df[num_features].fillna(median_values)

main_df[list_cat_col] = main_df[list_cat_col].replace("nan", "missing")
# Out:
# C:\Users\Никита\AppData\Local\Temp\ipykernel_2072\720946790.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   main_df[num_features] = main_df[num_features].fillna(median_values)
# C:\Users\Никита\AppData\Local\Temp\ipykernel_2072\720946790.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   main_df[list_cat_col] = main_df[list_cat_col].replace("nan", "missing")

# %%
main_df
# Out:
#         TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  \
# 0             2987000        0          86400       68.500000         W
# 1             2987001        0          86401       29.000000         W
# 2             2987002        0          86469       59.000000         W
# 3             2987003        0          86499       50.000000         W
# 4             2987004        0          86506       50.000000         H
# ...               ...      ...            ...             ...       ...
# 590535        3577535        0       15811047       49.000000         W
# 590536        3577536        0       15811049       39.500000         W
# 590537        3577537        0       15811079       30.953125         W
# 590538        3577538        0       15811088      117.000000         W
# 590539        3577539        0       15811131      280.000000         W
#
#           card1  card2  card3       card4  card5  ... id_32      id_33  \
# 0       13926.0  361.0  150.0    discover  142.0  ...  24.0    missing
# 1        2755.0  404.0  150.0  mastercard  102.0  ...  24.0    missing
# 2        4663.0  490.0  150.0        visa  166.0  ...  24.0    missing
# 3       18132.0  567.0  150.0  mastercard  117.0  ...  24.0    missing
# 4        4497.0  514.0  150.0  mastercard  102.0  ...  32.0  2220x1080
# ...         ...    ...    ...         ...    ...  ...   ...        ...
# 590535   6550.0  361.0  150.0        visa  226.0  ...  24.0    missing
# 590536  10444.0  225.0  150.0  mastercard  224.0  ...  24.0    missing
# 590537  12037.0  595.0  150.0  mastercard  224.0  ...  24.0    missing
# 590538   7826.0  481.0  150.0  mastercard  224.0  ...  24.0    missing
# 590539  15066.0  170.0  150.0  mastercard  102.0  ...  24.0    missing
#
#                  id_34    id_35    id_36    id_37    id_38  DeviceType  \
# 0              missing  missing  missing  missing  missing     missing
# 1              missing  missing  missing  missing  missing     missing
# 2              missing  missing  missing  missing  missing     missing
# 3              missing  missing  missing  missing  missing     missing
# 4       match_status:2        T        F        T        T      mobile
# ...                ...      ...      ...      ...      ...         ...
# 590535         missing  missing  missing  missing  missing     missing
# 590536         missing  missing  missing  missing  missing     missing
# 590537         missing  missing  missing  missing  missing     missing
# 590538         missing  missing  missing  missing  missing     missing
# 590539         missing  missing  missing  missing  missing     missing
#
#                            DeviceInfo  hour
# 0                             missing   0.0
# 1                             missing   0.0
# 2                             missing   0.0
# 3                             missing   0.0
# 4       SAMSUNG SM-G892A Build/NRD90M   0.0
# ...                               ...   ...
# 590535                        missing  23.0
# 590536                        missing  23.0
# 590537                        missing  23.0
# 590538                        missing  23.0
# 590539                        missing  23.0
#
# [590540 rows x 423 columns]

# %% [markdown]
# # Split data

# %%
y = main_df['isFraud']
main_df = main_df.drop('isFraud', axis=1)
data = main_df.drop(columns=['TransactionID', 'TransactionDT'])

X_train, X_test, y_train, y_test = train_test_split(data, y, test_size=0.2, random_state=42)

# %% [markdown]
# # Undersampling

# %%
# На таргет не сбалансирован, попробуем это исправит с помощью метода RandomUnderSampler
rus = RandomUnderSampler(random_state=42)
X_train_rus, y_train_rus= rus.fit_resample(X_train, y_train)

print(f'До отбора: {Counter(y_train)}')
print(f'После отбора: {Counter(y_train_rus)}')
# Out:
# До отбора: Counter({0: 455826, 1: 16606})
# После отбора: Counter({0: 16606, 1: 16606})

# %%
X_train_rus
# Out:
#        TransactionAmt ProductCD    card1  card2  card3       card4  card5  \
# 0           53.937500         W  11333.0  555.0  150.0        visa  226.0
# 1          200.000000         W  18132.0  567.0  150.0  mastercard  117.0
# 2          100.000000         H  15497.0  490.0  150.0        visa  226.0
# 3           39.000000         W  17188.0  321.0  150.0        visa  226.0
# 4          226.000000         W  17570.0  555.0  150.0        visa  226.0
# ...               ...       ...      ...    ...    ...         ...    ...
# 33207       40.000000         W   3507.0  361.0  150.0        visa  226.0
# 33208      335.000000         W   6019.0  583.0  150.0        visa  226.0
# 33209      141.000000         W   7919.0  194.0  150.0  mastercard  202.0
# 33210        3.828125         C   9917.0  142.0  185.0        visa  138.0
# 33211      122.000000         W  15185.0  332.0  150.0        visa  226.0
#
#         card6  addr1  addr2  ...  id_32      id_33           id_34    id_35  \
# 0       debit  433.0   87.0  ...   24.0    missing         missing  missing
# 1       debit  272.0   87.0  ...   24.0    missing         missing  missing
# 2       debit  299.0   87.0  ...   24.0  2880x1800  match_status:2        T
# 3       debit  315.0   87.0  ...   24.0    missing         missing  missing
# 4       debit  181.0   87.0  ...   24.0    missing         missing  missing
# ...       ...    ...    ...  ...    ...        ...             ...      ...
# 33207  credit  204.0   87.0  ...   24.0    missing         missing  missing
# 33208  credit  325.0   87.0  ...   24.0    missing         missing  missing
# 33209   debit  469.0   87.0  ...   24.0    missing         missing  missing
# 33210   debit  299.0   87.0  ...   24.0    missing         missing        F
# 33211   debit  205.0   87.0  ...   24.0    missing         missing  missing
#
#          id_36    id_37    id_38  DeviceType                   DeviceInfo  \
# 0      missing  missing  missing     missing                      missing
# 1      missing  missing  missing     missing                      missing
# 2            F        T        T     desktop                      Windows
# 3      missing  missing  missing     missing                      missing
# 4      missing  missing  missing     missing                      missing
# ...        ...      ...      ...         ...                          ...
# 33207  missing  missing  missing     missing                      missing
# 33208  missing  missing  missing     missing                      missing
# 33209  missing  missing  missing     missing                      missing
# 33210        F        T        F      mobile  RNE-L03 Build/HUAWEIRNE-L03
# 33211  missing  missing  missing     missing                      missing
#
#        hour
# 0      13.0
# 1       0.0
# 2      21.0
# 3      19.0
# 4      15.0
# ...     ...
# 33207  21.0
# 33208  13.0
# 33209   5.0
# 33210   8.0
# 33211  22.0
#
# [33212 rows x 420 columns]

# %% [markdown]
# # Закодируем фичи с помощью ohe и woe, отберем признаки по Log Reg, и обучим на модели Log Reg и Random Forest

# %% [markdown]
# Категориальные фичи попробуем закодировать с помощью двух методов. One Hot Encoded - для фичией с менее 5ти уникальными признаками и Weight of Evidence - для фичей с более 5ти уникальными признками

# %%
# для начала отберем эти признаки
to_ohe=[]
to_emb=[]
for c in list_cat_col:
    if X_train_rus[c].nunique() < 5:
        to_ohe.append(c)
    else:
        to_emb.append(c)

# %%
scaler = StandardScaler()

# Категориальный фичи < 5 уникальных значений будем кадировать OHE
ohe = OneHotEncoder(handle_unknown='ignore')

# Категориальный фичи >= 5 уникальных значений будем кадировать Weight of Evidence
woe = WOEEncoder()


column_trans = ColumnTransformer(
    [ ('scaler',scaler, num_features),
    ('ohe', ohe, to_ohe),
    ('woe', woe, to_emb)], remainder='passthrough', n_jobs=-1)



train_X_transformed = column_trans.fit_transform(X_train_rus, y_train_rus)
test_X_transformed = column_trans.transform(X_test)


print(train_X_transformed.shape)
# Out:
# (33212, 465)

# %%
train_X_transformed = pd.DataFrame(train_X_transformed)

# %% [markdown]
# Выберем признаки с помощью модели Log Reg

# %%
feature_log_reg = LogisticRegression(penalty='l1', max_iter=5000, solver='liblinear').fit(train_X_transformed, y_train_rus)
model = SelectFromModel(feature_log_reg, threshold=0.1, prefit=True)
X_train_new = model.transform(train_X_transformed)
X_test_new = model.transform(test_X_transformed)

# %% [markdown]
# Используем модель Log Reg для обучения модели, подбираем нужные параметры с помощью GridSearch

# %%
grid={"C":np.logspace(0,3,100), "penalty":["l1","l2"]}# l1 lasso l2 ridge
logreg = LogisticRegression(max_iter=10000)
logreg_cv = GridSearchCV(logreg,grid, scoring='roc_auc', cv=3, verbose=2)
logreg_cv.fit(X_train_new,y_train_rus)
print("tuned hpyerparameters :(best parameters) ",logreg_cv.best_params_)
print("accuracy :",logreg_cv.best_score_)
# Out:
# Fitting 3 folds for each of 200 candidates, totalling 600 fits
# [CV] END ..................................C=1.0, penalty=l1; total time=   0.0s
# [CV] END ..................................C=1.0, penalty=l1; total time=   0.0s
# [CV] END ..................................C=1.0, penalty=l1; total time=   0.0s
# [CV] END ..................................C=1.0, penalty=l2; total time=   1.8s
# [CV] END ..................................C=1.0, penalty=l2; total time=   1.4s
# [CV] END ..................................C=1.0, penalty=l2; total time=   1.5s
# [CV] END ...................C=1.0722672220103233, penalty=l1; total time=   0.0s
# [CV] END ...................C=1
best_estim.fit(X_train_new,y_train_rus)
prediction = best_estim.predict(X_test_new)

# %%
ras = roc_auc_score(y_test, prediction)
f = f1_score(y_test, prediction, average='micro')
cm = confusion_matrix(y_test, prediction)
pr = precision_score(y_test, prediction)
rc = recall_score(y_test, prediction)


print(f'ROC_AUC: {ras}, f1: {f}')
print(f'precision_score: {pr}')
print(f'recall_score: {rc}')
print(f'\nconfusion_matrix:\n{cm}')
# Out:
# ROC_AUC: 0.7875878016136968, f1: 0.2311445806278096
# precision_score: 0.13691397360036414
# recall_score: 0.7414345575548434
#
# confusion_matrix:
# [[95089 18962]
#  [ 1049  3008]]

# %% [markdown]
# Далее попробуем обучить на RandomForest

# %%
clf_rf_down = RandomForestClassifier(random_state=42)
model_rf_down = clf_rf_down.fit(train_X_transformed, y_train_rus)
x_prob_rf = model_rf_down.predict(test_X_transformed)

# %%
ras = roc_auc_score(y_test, x_prob_rf)
f = f1_score(y_test, x_prob_rf, average='micro')
cm = confusion_matrix(y_test, x_prob_rf)
pr = precision_score(y_test, x_prob_rf)
rc = recall_score(y_test, x_prob_rf)


print(f'ROC_AUC: {ras}, f1: {f}')
print(f'precision_score: {pr}')
print(f'recall_score: {rc}')
print(f'\nconfusion_matrix:\n{cm}')
# Out:
# ROC_AUC: 0.8519471504113528, f1: 0.8699326040573034
# precision_score: 0.18703283317645755
# recall_score: 0.8326349519349273
#
# confusion_matrix:
# [[99368 14683]
#  [  679  3378]]

# %% [markdown]
# # Попробуем использовать PCA для выбора фичей, вместо Log Reg

# %%
pca = PCA(n_components=0.95)
X_train_pca = pca.fit_transform(train_X_transformed)
X_test_pca = pca.transform(test_X_transformed)

# %% [markdown]
# Для начала обучим на Log Reg

# %%
grid={"C":np.logspace(0,3,20), "penalty":["l1","l2"]}# l1 lasso l2 ridge
logreg = LogisticRegression(max_iter=5000)
logreg_cv = GridSearchCV(logreg,grid, scoring='roc_auc', cv=3, verbose=2)
logreg_cv.fit(X_train_pca,y_train_rus)
print("tuned hpyerparameters :(best parameters) ",logreg_cv.best_params_)
print("accuracy :",logreg_cv.best_score_)
# Out:
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [CV] END ..................................C=1.0, penalty=l1; total time=   0.0s
# [CV] END ..................................C=1.0, penalty=l1; total time=   0.0s
# [CV] END ..................................C=1.0, penalty=l1; total time=   0.0s
# [CV] END ..................................C=1.0, penalty=l2; total time=   0.4s
# [CV] END ..................................C=1.0, penalty=l2; total time=   0.5s
# [CV] END ..................................C=1.0, penalty=l2; total time=   0.5s
# [CV] END ...................C=1.4384498882876628, penalty=l1; total time=   0.0s
# [CV] END ...................C=1.4384498882876628, penalty=l1; total time=   0.0s
# [CV] END ...................C=1.4384498882876628, penalty=l1; total time=   0.0s
# [CV] END ...................C=1.4384498882876628, penalty=l2; total time=   0.4s
# [CV] END ...................C=1.4384498882876628, penalty=l2; total time=   0.5s
# [CV] END ...................C=1.4384498882876628, penalty=l2; total time=   0.4s
# [CV] END ...................C=2.0691380811147897, penalty=l1; total time=   0.0s
# [CV] END ...................C=2.0691380811147897, penalty=l1; total time=   0.0s
# [CV] END ...................C=2.0691380811147897, penalty=l1; total time=   0.0s
# [CV] END ...................C=2.0691380811147897, penalty=l2; total time=   0.5s
# [CV] END ....................C=483.2930238571752, penalty=l1; total time=   0.0s
# [CV] END ....................C=483.2930238571752, penalty=l1; total time=   0.0s
# [CV] END ....................C=483.2930238571752, penalty=l2; total time=   0.4s
# [CV] END ....................C=483.2930238571752, penalty=l2; total time=   0.5s
# [CV] END ....................C=483.2930238571752, penalty=l2; total time=   0.5s
# [CV] END ....................C=695.1927961775606, penalty=l1; total time=   0.0s
# [CV] END ....................C=695.1927961775606, penalty=l1; total time=   0.0s
# [CV] END ....................C=695.1927961775606, penalty=l1; total time=   0.0s
# [CV] END ....................C=695.1927961775606, penalty=l2; total time=   0.4s
# [CV] END ....................C=695.1927961775606, penalty=l2; total time=   0.5s
# [CV] END ....................C=695.1927961775606, penalty=l2; total time=   0.6s
# [CV] END ...............................C=1000.0, penalty=l1; total time=   0.0s
# [CV] END ...............................C=1000.0, penalty=l1; total time=   0.0s
# [CV] END ...............................C=1000.0, penalty=l1; total time=   0.0s
# [CV] END ...............................C=1000.0, penalty=l2; total time=   0.4s
# [CV] END ...............................C=1000.0, penalty=l2; total time=   0.5s
# [CV] END ...............................C=1000.0, penalty=l2; total time=   0.5s
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 60 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 60 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [       nan 0.85036335        nan 0.85037762        nan 0.85039053
#         nan 0.8503982         nan 0.85041096        nan 0.85041081
#         nan 0.85041222        nan 0.85042366        nan 0.8504362
#         nan 0.85042594        nan 0.85042902        nan 0.85043268
#         nan 0.85043104        nan 0.85042807        nan 0.85043427
#         nan 0.85043219        nan 0.85043169        nan 0.85042871
#         nan 0.85043451        nan 0.85043607]
#   warnings.warn(
# tuned hpyerparameters :(best parameters)  {'C': 18.329807108324356, 'penalty': 'l2'}
# accuracy : 0.8504361993563411

# %%
best_estim_pca = logreg_cv.best_estimator_
best_estim_pca.fit(X_train_pca,y_train_rus)
prediction_pca = best_estim_pca.predict(X_test_pca)

# %%
ras = roc_auc_score(y_test, prediction_pca)
f = f1_score(y_test, prediction_pca, average='micro')
cm = confusion_matrix(y_test, prediction_pca)
pr = precision_score(y_test, prediction_pca)
rc = recall_score(y_test, prediction_pca)


print(f'ROC_AUC: {ras}, f1: {f}')
print(f'precision_score: {pr}')
print(f'recall_score: {rc}')
print(f'\nconfusion_matrix:\n{cm}')
# Out:
# ROC_AUC: 0.7632612095898952, f1: 0.8203169980018288
# precision_score: 0.12457897729758104
# recall_score: 0.7019965491742667
#
# confusion_matrix:
# [[94038 20013]
#  [ 1209  2848]]

# %% [markdown]
# Обучим на модели RandomForest

# %%
clf_rf_down = RandomForestClassifier(random_state=42)
model_rf_down = clf_rf_down.fit(X_train_pca, y_train_rus)
# y_pred = model_rf_down.predict(X_test)
x_prob_rf = model_rf_down.predict(X_test_pca)
# Out:
# ROC_AUC: 0.8123089139834864

# %%
ras = roc_auc_score(y_test, x_prob_rf)
f = f1_score(y_test, x_prob_rf, average='micro')
cm = confusion_matrix(y_test, x_prob_rf)
pr = precision_score(y_test, x_prob_rf)
rc = recall_score(y_test, x_prob_rf)


print(f'ROC_AUC: {ras}, f1: {f}')
print(f'precision_score: {pr}')
print(f'recall_score: {rc}')
print(f'\nconfusion_matrix:\n{cm}')
# Out:
# ROC_AUC: 0.8519471504113528, f1: 0.8699326040573034
# precision_score: 0.18703283317645755
# recall_score: 0.8326349519349273
#
# confusion_matrix:
# [[99368 14683]
#  [  679  3378]]

# %% [markdown]
# # XGBoost Model

# %%
# подбираем оптимальные параметры для XGBoost
parameters = {
              'max_depth': [5, 10, 15, 20, 25],
              'learning_rate': [0.01, 0.02, 0.05, 0.1, 0.15],
              'n_estimators': range(100, 1000,200 ),
              'min_child_weight': [0, 2, 5, 10, 20],
              'max_delta_step': [0, 0.2, 0.6, 1, 2],
              'subsample': [0.6, 0.7, 0.8, 0.85, 0.95],
              'colsample_bytree': [0.5, 0.6, 0.7, 0.8, 0.9],
              'reg_alpha': [0, 0.25, 0.5, 0.75, 1],
              'reg_lambda': [0.2, 0.4, 0.6, 0.8, 1],
              'scale_pos_weight': [0.2, 0.4, 0.6, 0.8, 1]}
 


estimator = XGBClassifier(
    objective= 'binary:logistic',
    nthread=4,
    seed=42
)

clf = GridSearchCV(estimator=estimator, 
                   param_grid=params,
                   scoring='neg_mean_squared_error', 
                   cv=4,
                   verbose=2)
clf.fit(train_X_transformed, y_train_rus)

print("Best parameters:", clf.best_params_)
print("accuracy :",clf.best_score_)
# Out:
# Fitting 4 folds for each of 54 candidates, totalling 216 fits
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=100; total time=   1.6s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=100; total time=   1.6s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=100; total time=   1.6s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=100; total time=   1.5s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   7.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   7.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   7.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   7.3s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=1000; total time=  14.3s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=1000; total time=  14.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=1000; total time=  14.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=1000; total time=  14.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   2.5s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   2.5s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   2.5s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   2.5s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=500; total time=  11.7s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=500; total time=  11.8s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=500; total time=  11.7s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=500; total time=  13.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=1000; total time=  24.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=1000; total time=  25.7s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=1000; total time=  23.6s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=1000; total time=  26.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=100; total time=   4.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=100; total time=   4.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=100; total time=   4.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=100; total time=   4.3s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=500; total time=  22.7s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=500; total time=  22.3s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=500; total time=  19.5s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=500; total time=  22.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=1000; total time=  40.5s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=1000; total time=  42.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=1000; total time=  41.6s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=1000; total time=  40.7s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=100; total time=   1.6s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=100; total time=   1.7s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=100; total time=   1.6s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=100; total time=   1.6s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=500; total time=   7.3s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=500; total time=   9.6s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=500; total time=   8.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=500; total time=   7.3s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=1000; total time=  14.3s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=1000; total time=  17.3s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=1000; total time=  14.3s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=1000; total time=  16.8s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=100; total time=   2.9s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=100; total time=   2.5s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=100; total time=   2.5s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=100; total time=   2.5s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=500; total time=  11.6s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=500; total time=  14.7s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=500; total time=  11.5s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=500; total time=  12.3s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=1000; total time=  25.6s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=1000; total time=  26.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=1000; total time=  24.9s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=1000; total time=  24.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=100; total time=   4.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=100; total time=   5.5s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=100; total time=   5.5s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=100; total time=   4.4s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=500; total time=  18.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=500; total time=  21.3s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=500; total time=  19.9s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=500; total time=  19.4s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=1000; total time=  39.3s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=1000; total time=  40.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=1000; total time=  40.6s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=1000; total time=  38.8s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   1.6s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   1.6s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   1.6s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   1.6s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   7.3s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   7.6s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   9.8s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   7.3s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=  14.3s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=  16.4s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=  15.4s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=  14.3s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   2.9s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   3.4s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   3.3s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   3.3s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=500; total time=  11.6s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=500; total time=  11.7s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=500; total time=  14.4s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=500; total time=  11.6s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=1000; total time=  26.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=1000; total time=  24.3s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=1000; total time=  24.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=1000; total time=  26.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=100; total time=   4.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=100; total time=   4.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=100; total time=   3.9s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=100; total time=   5.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=500; total time=  20.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=500; total time=  20.9s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=500; total time=  18.3s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=500; total time=  20.9s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=1000; total time=  38.3s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=1000; total time=  38.6s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=1000; total time=  39.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=1000; total time=  40.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=100; total time=   3.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=100; total time=   2.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=100; total time=   2.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=100; total time=   2.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=500; total time=  12.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=500; total time=  14.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=500; total time=  12.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=500; total time=  12.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=1000; total time=  27.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=1000; total time=  27.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=1000; total time=  27.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=1000; total time=  24.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   6.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   5.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   4.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   4.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=500; total time=  24.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=500; total time=  23.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=500; total time=  23.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=500; total time=18.3min
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=1000; total time=  43.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=1000; total time=  44.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=1000; total time=  44.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=1000; total time=  45.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=100; total time=   8.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=100; total time=   7.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=100; total time=   7.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=100; total time=   8.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=500; total time=  40.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=500; total time=  40.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=500; total time=  40.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=500; total time=  39.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=1000; total time= 1.3min
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=1000; total time= 1.3min
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=1000; total time= 1.3min
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=1000; total time= 1.3min
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=100; total time=   3.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=100; total time=   3.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=100; total time=   2.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=100; total time=   2.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=500; total time=  12.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=500; total time=  14.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=500; total time=  12.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=500; total time=  12.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=1000; total time=  27.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=1000; total time=  27.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=1000; total time=  25.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=1000; total time=  26.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=100; total time=   5.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=100; total time=   6.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=100; total time=   5.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=100; total time=   4.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=500; total time=  24.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=500; total time=  22.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=500; total time=  24.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=500; total time=  24.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=1000; total time=  46.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=1000; total time=  48.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=1000; total time=  47.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=1000; total time=  47.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=100; total time=  10.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=100; total time=   7.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=100; total time=   7.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=100; total time=   9.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=500; total time=  39.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=500; total time=  38.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=500; total time=  38.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=500; total time=  40.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=1000; total time= 1.3min
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=1000; total time= 1.3min
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=1000; total time= 1.3min
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=1000; total time= 1.3min
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   3.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   3.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   3.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   2.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=500; total time=  12.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=500; total time=  13.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=500; total time=  14.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=500; total time=  12.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=  28.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=  28.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=  27.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=  25.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   6.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   5.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   4.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   4.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=500; total time=  25.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=500; total time=  23.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=500; total time=  24.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=500; total time=  25.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=1000; total time=  48.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=1000; total time=  49.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=1000; total time=  48.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=1000; total time=  48.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100; total time=   7.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100; total time=   7.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100; total time=  10.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100; total time=   8.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500; total time=  39.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500; total time=  39.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500; total time=  42.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500; total time=  38.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=1000; total time= 1.3min
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=1000; total time= 1.3min
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=1000; total time= 1.3min
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=1000; total time= 1.3min
# Best parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 1000}
# accuracy : -0.11053233770926171

# %%
best_estim_XGB = clf.best_estimator_
best_estim_XGB.fit(train_X_transformed,y_train_rus)
prediction_XGB = best_estim_XGB.predict(test_X_transformed)

# %%
ras = roc_auc_score(y_test, prediction_XGB)
f = f1_score(y_test, prediction_XGB, average='micro')
cm = confusion_matrix(y_test, prediction_XGB)
pr = precision_score(y_test, prediction_XGB)
rc = recall_score(y_test, prediction_XGB)


print(f'ROC_AUC: {ras}, f1: {f}')
print(f'precision_score: {pr}')
print(f'recall_score: {rc}')
print(f'\nconfusion_matrix:\n{cm}')
# Out:
# ROC_AUC: 0.8971257441192427, f1: 0.9094388187083009
# precision_score: 0.2596481065817102
# recall_score: 0.8839043628296771
#
# confusion_matrix:
# [[103826  10225]
#  [   471   3586]]

# %% [markdown]
# ### Результаты
#
# Undersampling| Encoder | Feature selection | Model | ROC-AUC | F1-score |precision_score | recall_score
# ---| --- |---| --- | --- | --- | ---| ---
# Random Sampler| ohe и woe | Logistic Regression | Logistic Regression | 0.78 | 0.23 | 0.13 | 0.74
# Random Sampler| ohe и woe| PCA | Logistic Regression | 0.76 | 0.82 | 0.12 | 0.70
# Random Sampler| ohe и woe | Logistic Regression | RandomForest | 0.85 | 0.87 | 0.18 | 0.83
# Random Sampler| ohe и woe| PCA |  RandomForest | 0.85 | 0.87 | 0.19 | 0.83
# Random Sampler| ohe и woe | | XGBoost | 0.9 | 0.91 | 0.25 | 0.88
